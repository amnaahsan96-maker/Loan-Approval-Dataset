# %% [markdown]
# #
# # Project Title:
# # Data Preprocessing, Cleaning, visualization of
# #         Dataset name: "Loan Approval Dataset "

# %% [markdown]
# # ** Submitted by:Bushra Shaukat**
# # Submitted to: Sir Muhammad Ansar

# %% [markdown]
# **Importing Libraries**

# %% [markdown]
# **We need three Libraries for data manipulation.cleaning, visualization.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **importing Dataset**

# %% [markdown]
# **downloaded kaggle**

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/MyDrive/loanapproval.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **A- Data inpections**

# %% [markdown]
# **1-checking ist five rows**

# %%
df.head()
# Out:
#    applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0             1   59    Male       Divorced         100073         7169
# 1             2   49    Male        Married         112197        23556
# 2             3   35    Male       Divorced          84429        27052
# 3             4   63  Female         Single         124195        11313
# 4             5   28  Female        Married          81627        13315
#
#    credit_score  num_dependents  existing_loans_count employment_status  \
# 0           793               1                     1        Unemployed
# 1           789               0                     2          Employed
# 2           372               1                     4        Unemployed
# 3           808               3                     4     Self-employed
# 4           689               0                     1        Unemployed
#
#    loan_approved
# 0              1
# 1              1
# 2              0
# 3              1
# ...

# %% [markdown]
# **2-checking last five rows**

# %%
df.tail()
# Out:
#      applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 995           996   53  Female        Married         135598         6014
# 996           997   22    Male         Single         139028        15103
# 997           998   34  Female        Married         147517        21986
# 998           999   60  Female       Divorced          73161        49781
# 999          1000   60  Female         Single         141316        35471
#
#      credit_score  num_dependents  existing_loans_count employment_status  \
# 995           767               3                     2          Employed
# 996           662               0                     0     Self-employed
# 997           582               0                     2          Employed
# 998           635               4                     0        Unemployed
# 999           461               1                     1        Unemployed
#
#      loan_approved
# 995              1
# 996              1
# ...

# %% [markdown]
# **3-checking details**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   applicant_id          1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   gender                1000 non-null   object
#  3   marital_status        1000 non-null   object
#  4   annual_income         1000 non-null   int64
#  5   loan_amount           1000 non-null   int64
#  6   credit_score          1000 non-null   int64
#  7   num_dependents        1000 non-null   int64
#  8   existing_loans_count  1000 non-null   int64
#  9   employment_status     1000 non-null   object
#  10  loan_approved         1000 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 86.1+ KB

# %% [markdown]
# **4.Checking Rows and Coloumns:**

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# **5.Column Names**

# %%
df.columns
# Out:
# Index(['applicant_id', 'age', 'gender', 'marital_status', 'annual_income',
#        'loan_amount', 'credit_score', 'num_dependents', 'existing_loans_count',
#        'employment_status', 'loan_approved'],
#       dtype='object')

# %% [markdown]
# **6.Data Types for Preprocessing**

# %%
df.dtypes
# Out:
# applicant_id             int64
# age                      int64
# gender                  object
# marital_status          object
# annual_income            int64
# loan_amount              int64
# credit_score             int64
# num_dependents           int64
# existing_loans_count     int64
# employment_status       object
# loan_approved            int64
# dtype: object

# %% [markdown]
# **7.Label-based Data Selection (row and column)**

# %%
df.loc[1]
# Out:
# applicant_id                   2
# age                           49
# gender                      Male
# marital_status           Married
# annual_income             112197
# loan_amount                23556
# credit_score                 789
# num_dependents                 0
# existing_loans_count           2
# employment_status       Employed
# loan_approved                  1
# Name: 1, dtype: object

# %%
df.loc[0:2, ['age', 'loan_amount']]
# Out:
#    age  loan_amount
# 0   59         7169
# 1   49        23556
# 2   35        27052

# %%
df.loc[550:555,['age','loan_amount']]
# Out:
#      age  loan_amount
# 550   45        24710
# 551   41        48178
# 552   56        29532
# 553   43        23601
# 554   36         9967
# 555   59        23753

# %% [markdown]
# **8.Index-based Data Selection (row and column)**

# %%
df.iloc[:, [1,5,6]]
# Out:
#      age  loan_amount  credit_score
# 0     59         7169           793
# 1     49        23556           789
# 2     35        27052           372
# 3     63        11313           808
# 4     28        13315           689
# ..   ...          ...           ...
# 995   53         6014           767
# 996   22        15103           662
# 997   34        21986           582
# 998   60        49781           635
# 999   60        35471           461
#
# [1000 rows x 3 columns]

# %% [markdown]
# **9.Frequency Distribution of Values using value_counts()**

# %% [markdown]
# **Gender Distribution**

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      524
# Female    476
# Name: count, dtype: int64

# %% [markdown]
# **Marital Status Count**

# %%
df['marital_status'].value_counts()
# Out:
# marital_status
# Married     355
# Single      342
# Divorced    303
# Name: count, dtype: int64

# %% [markdown]
# **Employment Status Distribution**

# %%
df['employment_status'].value_counts()
# Out:
# employment_status
# Self-employed    350
# Unemployed       330
# Employed         320
# Name: count, dtype: int64

# %% [markdown]
# **Loan Approval Status**

# %%
df['loan_approved'].value_counts()
# Out:
# loan_approved
# 1    729
# 0    271
# Name: count, dtype: int64

# %% [markdown]
# **Existing Loans Count**

# %%
df['existing_loans_count'].value_counts()
# Out:
# existing_loans_count
# 1    229
# 4    212
# 3    205
# 0    179
# 2    175
# Name: count, dtype: int64

# %% [markdown]
# **Applying mathematical fuctions**

# %%
df.describe()
# Out:
#        applicant_id          age  annual_income   loan_amount  credit_score  \
# count   1000.000000  1000.000000    1000.000000   1000.000000   1000.000000
# mean     500.500000    42.515000   81972.972000  27244.866000    576.125000
# std      288.819436    12.611059   37547.255418  12822.752877    155.921483
# min        1.000000    21.000000   20155.000000   5082.000000    300.000000
# 25%      250.750000    32.000000   48913.250000  16587.500000    443.750000
# 50%      500.500000    43.000000   82050.000000  27041.500000    573.500000
# 75%      750.250000    53.000000  113556.000000  37939.250000    713.250000
# max     1000.000000    64.000000  149951.000000  49864.000000    849.000000
#
#        num_dependents  existing_loans_count  loan_approved
# count      1000.00000           1000.000000    1000.000000
# mean          1.97700              2.042000       0.729000
# std           1.41862              1.413589       0.444699
# ...

# %% [markdown]
# # B-Data Cleaning

# %% [markdown]
# **1-checking Missing Values**

# %%
df.isnull()
# Out:
#      applicant_id    age  gender  marital_status  annual_income  loan_amount  \
# 0           False  False   False           False          False        False
# 1           False  False   False           False          False        False
# 2           False  False   False           False          False        False
# 3           False  False   False           False          False        False
# 4           False  False   False           False          False        False
# ..            ...    ...     ...             ...            ...          ...
# 995         False  False   False           False          False        False
# 996         False  False   False           False          False        False
# 997         False  False   False           False          False        False
# 998         False  False   False           False          False        False
# 999         False  False   False           False          False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# applicant_id            0
# age                     0
# gender                  0
# marital_status          0
# annual_income           0
# loan_amount             0
# credit_score            0
# num_dependents          0
# existing_loans_count    0
# employment_status       0
# loan_approved           0
# dtype: int64

# %% [markdown]
# **2."Non-Null Values in Dataset"**

# %%
df.notnull()
# Out:
#      applicant_id   age  gender  marital_status  annual_income  loan_amount  \
# 0            True  True    True            True           True         True
# 1            True  True    True            True           True         True
# 2            True  True    True            True           True         True
# 3            True  True    True            True           True         True
# 4            True  True    True            True           True         True
# ..            ...   ...     ...             ...            ...          ...
# 995          True  True    True            True           True         True
# 996          True  True    True            True           True         True
# 997          True  True    True            True           True         True
# 998          True  True    True            True           True         True
# 999          True  True    True            True           True         True
#
# ...

# %% [markdown]
# **3.Remove Missing Values**

# %%
df.dropna()
# Out:
#      applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0               1   59    Male       Divorced         100073         7169
# 1               2   49    Male        Married         112197        23556
# 2               3   35    Male       Divorced          84429        27052
# 3               4   63  Female         Single         124195        11313
# 4               5   28  Female        Married          81627        13315
# ..            ...  ...     ...            ...            ...          ...
# 995           996   53  Female        Married         135598         6014
# 996           997   22    Male         Single         139028        15103
# 997           998   34  Female        Married         147517        21986
# 998           999   60  Female       Divorced          73161        49781
# 999          1000   60  Female         Single         141316        35471
#
#      credit_score  num_dependents  existing_loans_count employment_status  \
# ...

# %% [markdown]
# **4.Fill Missing Values**

# %%
df.interpolate()
# Out:
# /tmp/ipython-input-4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#      applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0               1   59    Male       Divorced         100073         7169
# 1               2   49    Male        Married         112197        23556
# 2               3   35    Male       Divorced          84429        27052
# 3               4   63  Female         Single         124195        11313
# 4               5   28  Female        Married          81627        13315
# ..            ...  ...     ...            ...            ...          ...
# 995           996   53  Female        Married         135598         6014
# 996           997   22    Male         Single         139028        15103
# 997           998   34  Female        Married         147517        21986
# ...

# %% [markdown]
# **5.Checking Duplicate Records**

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# **6.Removing Duplicate Records**

# %%
df.drop_duplicates()
# Out:
#      applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0               1   59    Male       Divorced         100073         7169
# 1               2   49    Male        Married         112197        23556
# 2               3   35    Male       Divorced          84429        27052
# 3               4   63  Female         Single         124195        11313
# 4               5   28  Female        Married          81627        13315
# ..            ...  ...     ...            ...            ...          ...
# 995           996   53  Female        Married         135598         6014
# 996           997   22    Male         Single         139028        15103
# 997           998   34  Female        Married         147517        21986
# 998           999   60  Female       Divorced          73161        49781
# 999          1000   60  Female         Single         141316        35471
#
#      credit_score  num_dependents  existing_loans_count employment_status  \
# ...

# %% [markdown]
# # **C-Numerical functions**

# %% [markdown]
# **1-mean**

# %%
df.mean(numeric_only=True)
# Out:
# applicant_id              500.500
# age                        42.515
# annual_income           81972.972
# loan_amount             27244.866
# credit_score              576.125
# num_dependents              1.977
# existing_loans_count        2.042
# loan_approved               0.729
# dtype: float64

# %% [markdown]
# **2-standard deviation**

# %%
df.std(numeric_only=True)
# Out:
# applicant_id              288.819436
# age                        12.611059
# annual_income           37547.255418
# loan_amount             12822.752877
# credit_score              155.921483
# num_dependents              1.418620
# existing_loans_count        1.413589
# loan_approved               0.444699
# dtype: float64

# %% [markdown]
# **3-Median**

# %%
df.median(numeric_only=True)
# Out:
# applicant_id              500.5
# age                        43.0
# annual_income           82050.0
# loan_amount             27041.5
# credit_score              573.5
# num_dependents              2.0
# existing_loans_count        2.0
# loan_approved               1.0
# dtype: float64

# %% [markdown]
# # Visualization

# %% [markdown]
# **Single line Graph**

# %% [markdown]
# **1.Age**

# %%
plt.plot(df['age'])
plt.xlabel('Applicant Id')
plt.ylabel('Age')
plt.title('Age of Loan Applicants')
plt.show()
# Out:
# Text(0.5, 1.0, 'Age of Loan Applicants')

# %% [markdown]
# **2.Annual income**

# %%
plt.plot(df['annual_income'])
plt.xlabel('Applicant ID')
plt.ylabel('Annual Income')
plt.title('Annual Income Trend')
plt.show()

# %%
plt.plot(df['annual_income'], marker='o', linestyle='-', color='orange')
plt.grid(True)
plt.xlabel('Applicant ID')
plt.ylabel('Annual Income')
plt.title('Annual Income Trend')
plt.show()

# %%
plt.plot(df['annual_income'][:50], marker='o', linestyle='-', color='orange')
plt.xlabel('Applicant ID')
plt.ylabel('Annual Income')
plt.title('Annual Income (First 50 Applicants)')
plt.grid(True)
plt.show()

# %% [markdown]
# **3.Loan Amount**

# %%
plt.plot(df['loan_amount'])
plt.xlabel('applicant_id')
plt.ylabel('loan_amount')
plt.title('Loan_amount Distribution')
plt.show()

# %% [markdown]
# 4.**credit_score**

# %%
plt.plot(df['applicant_id'], df['credit_score'], marker='o')
plt.xlabel("Applicant ID")
plt.ylabel("Credit Score")
plt.title("Credit Score Trend")
plt.show()

# %% [markdown]
# **5.num_dependents**

# %%
plt.plot(df['num_dependents'])
plt.xlabel('Applicant ID')
plt.ylabel('Number of Dependents')
plt.title('Dependents Distribution')
plt.show()

# %% [markdown]
# **6.existing_loans_count**

# %%
plt.plot(df['existing_loans_count'])
plt.xlabel('Applicant ID')
plt.ylabel('Existing Loans')
plt.title('Existing Loans Count Trend')
plt.show()

# %% [markdown]
# 7.**loan_approved**

# %%
plt.plot(df['loan_approved'])
plt.xlabel('Applicant ID')
plt.ylabel('Loan Approved')
plt.title('Loan Approval Trend')
plt.show()

# %% [markdown]
# **Multiple Line Graph**

# %% [markdown]
# **1️. Age vs Credit Score**

# %%
plt.plot(df['age'], label='Age')
plt.plot(df['credit_score'], label='Credit Score')
plt.xlabel('Applicant ID')
plt.ylabel('Value')
plt.title('Age vs Credit Score')
plt.legend()
plt.show()

# %% [markdown]
# **2.Loan Amount vs Credit Score**

# %%
plt.plot(df['loan_amount'], label='Loan Amount')
plt.plot(df['credit_score'], label='Credit Score')
plt.xlabel('Applicant ID')
plt.ylabel('Value')
plt.title('Loan Amount vs Credit Score')
plt.legend()
plt.show()

# %% [markdown]
# **3.Existing Loans vs Dependents**

# %%
plt.plot(df['existing_loans_count'], label='Existing Loans')
plt.plot(df['num_dependents'], label='Dependents')
plt.xlabel('Applicant ID')
plt.ylabel('Count')
plt.title('Existing Loans vs Dependents')
plt.legend()
plt.show()

# %% [markdown]
# **4.Dependents, Existing Loans and Loan Approval**

# %% [markdown]
# **Bar Graph**

# %% [markdown]
# **Gender**

# %%
df['gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **2.martial_status**

# %%
df['marital_status'].value_counts().plot(kind='bar')
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **3Employment_status**

# %%
df['employment_status'].value_counts().plot(kind='bar')
plt.title('Employment Status of Applicants')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **4.loan_approved (0 / 1)**

# %%
df['loan_approved'].value_counts().plot(kind='bar')
plt.title('Loan Approval Status')
plt.xlabel('Loan Approved')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Histrogram**

# %% [markdown]
# **1.Age Histrogram**

# %%
plt.hist(df['age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Applicants')
plt.show()

# %% [markdown]
# 2.**Annual Income Histogram**

# %%
plt.hist(df['annual_income'], bins=10, color='lightgreen', edgecolor='black')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.title('Annual Income Distribution')
plt.show()

# %% [markdown]
# **Loan Amount Distribution**

# %%
plt.hist(df['loan_amount'],bins=10,color='lightblue',edgecolor='black')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.title('Loan Amount Distribution')
plt.show()

# %% [markdown]
# **Credit Score Distribution**

# %%
plt.hist(df['credit_score'],bins=10,color='lightpink',edgecolor='black')
plt.xlabel('Credit Score')
plt.ylabel('Frequency')
plt.title('Credit Score Distribution')
plt.show()

# %% [markdown]
# **PIE CHARTS**

# %% [markdown]
# **Loan Approval Pie Chart**

# %%
df['loan_approved'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightgreen', 'lightpink']
)
plt.title('Loan Approval Percentage')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Gender Pie Chart**

# %%
df['employment_status'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightblue', 'lightgreen']
)
plt.title('Employment Status Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Employment Status Pie Chart**

# %%
df['employment_status'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightblue', 'lightgreen']
)
plt.title('Employment Status Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Scatter Graph**

# %% [markdown]
# **Credit Score vs Loan Amount**

# %%
plt.scatter(df['credit_score'], df['loan_amount'])
plt.xlabel('Credit Score')
plt.ylabel('Loan Amount')
plt.title('Credit Score vs Loan Amount')
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Conclusion:
# In this project, the loan approval dataset was analyzed using Pandas, NumPy, and Matplotlib. The data was inspected and cleaned using methods like head(), tail(), info(), describe(), isnull(), dropna(), and interpolate(). Histograms showed the distribution of numerical variables such as age, income, loan amount, and credit score. Line graphs and multiple line graphs helped observe trends and compare variables like income versus loan amount. Bar graphs and pie charts highlighted patterns in categorical variables like gender, marital status, and employment. Scatter plots revealed relationships between financial features and loan approval. The analysis showed that credit score, employment status, and dependents influence approval more than income alone. Outliers and missing data were effectively handled to improve data quality. Overall, the project demonstrates how Python libraries can clean, explore, analyze, and visualize real-world datasets. These insights provide a clear understanding of the factors affecting loan approval.
